# %%
from sklearn.datasets import load_diabetes

# %%
df1=load_diabetes()

# %%
print(df1['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
import pandas as pd
df=pd.DataFrame(df1.data,columns=['age','sex','bmi','bp','s1','s2','s3','s4','s5','s6'])

# %%
df.head()
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1 -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2  0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3 -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4  0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
#
# [5 rows x 10 columns]

# %%
x=df1
y=df1['target']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.3,random_state=42)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
cor=df.corr()
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 7, None],
    'min_samples_leaf': [1, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)

print("Best parameters found: ", grid_search.best_params_)
print("Best estimator found: ", grid_search.best_estimator_)
regressor.fit(x_train,y_train)
# Out:
# Best parameters found:  {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 2}
# Best estimator found:  DecisionTreeRegressor(max_depth=3, min_samples_leaf=5)
# DecisionTreeRegressor()

# %% [markdown]
# The best parameters found by GridSearchCV are: `{'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 2}`.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Get the best estimator from GridSearchCV
best_regressor = grid_search.best_estimator_

# Make predictions on the test set
y_pred = best_regressor.predict(x_test)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on Test Set: {mse:.2f}")

# Calculate R-squared (R2)
r2 = r2_score(y_test, y_pred)
print(f"R-squared on Test Set: {r2:.2f}")
# Out:
# Mean Squared Error on Test Set: 3207.59
# R-squared on Test Set: 0.41

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(regressor,filled=True)
# Out:
# [Text(0.5857033335044138, 0.9722222222222222, 'x[2] <= 0.005\nsquared_error = 6148.282\nsamples = 309\nvalue = 153.903'),
#  Text(0.33568248306302606, 0.9166666666666666, 'x[8] <= 0.014\nsquared_error = 3636.316\nsamples = 183\nvalue = 118.355'),
#  Text(0.46069290828371995, 0.9444444444444444, 'True  '),
#  Text(0.20513626565386983, 0.8611111111111112, 'x[5] <= 0.091\nsquared_error = 2641.993\nsamples = 138\nvalue = 102.855'),
#  Text(0.1589637651406282, 0.8055555555555556, 'x[8] <= -0.043\nsquared_error = 2392.062\nsamples = 136\nvalue = 100.816'),
#  Text(0.07647300349004311, 0.75, 'x[4] <= -0.039\nsquared_error = 1519.474\nsamples = 42\nvalue = 78.952'),
#  Text(0.05276123999178813, 0.6944444444444444, 'x[4] <= -0.046\nsquared_error = 1850.165\nsamples = 24\nvalue = 94.792'),
#  Text(0.03654280435228906, 0.6388888888888888, 'x[0] <= -0.0\nsquared_error = 1134.5\nsamples = 20\nvalue = 82.0'),
# ...

# %% [markdown]
# # Task
# Perform hyperparameter tuning for the `DecisionTreeRegressor` model using `GridSearchCV` to find the best parameters, and then evaluate the performance of the model with these best parameters.

# %% [markdown]
# ## Hyperparameter Tuning
#
# ### Subtask:
# Perform hyperparameter tuning for the DecisionTreeRegressor using GridSearchCV to find the best parameters.

# %% [markdown]
# **Reasoning**:
# The subtask is to perform hyperparameter tuning for the DecisionTreeRegressor using GridSearchCV. This step imports GridSearchCV, defines the parameter grid, instantiates GridSearchCV, fits it to the training data, and prints the best parameters and best estimator.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 7, None],
    'min_samples_leaf': [1, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(x_train, y_train)

print("Best parameters found: ", grid_search.best_params_)
print("Best estimator found: ", grid_search.best_estimator_)
# Out:
# Best parameters found:  {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 2}
# Best estimator found:  DecisionTreeRegressor(max_depth=3, min_samples_leaf=5)

# %% [markdown]
# ## Evaluate Best Model
#
# ### Subtask:
# Evaluate the performance of the DecisionTreeRegressor with the best parameters found during tuning.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   Hyperparameter tuning for the `DecisionTreeRegressor` model was performed using `GridSearchCV`.
# *   The optimal hyperparameters identified for the `DecisionTreeRegressor` were: `max_depth`: 3, `min_samples_leaf`: 5, and `min_samples_split`: 2.
# *   The tuning process utilized `neg_mean_squared_error` as the scoring metric and 5-fold cross-validation.
#
# ### Insights or Next Steps
# *   The next logical step is to evaluate the performance of the `DecisionTreeRegressor` using the identified best parameters on the test dataset to assess its generalization capability.
# *   The chosen `max_depth` of 3 suggests a relatively simple and interpretable model, which could be beneficial for understanding feature importance and decision paths.
